# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Fundamentos de Aprendizado de Máquina
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Teoria;</li>
#   <li>Atributos categóricos;</li>
#   <li>Atributos numéricos;</li>
#   <li>Dados faltantes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Pinguins

# %% [markdown]
# Neste exercício, vamos utilizar uma base de dados com informações sobre penguins. A idéia é preparar a base de dados para prever a espécie do penguin (variável resposta) baseado em suas características físicas e geográficas (variáveis preditivas).

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset('penguins')

# %%
data.head(10)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male

# %% [markdown]
# ### **1.1. Valores nulos**

# %% [markdown]
# A base de dados possui valores faltantes, utilize os conceitos da aula para trata-los.

# %%
# resposta da questão 1.1

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
data.isna().sum() # vê quantos nulos tem
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
data = data.dropna(how='any', axis= 0) #eliminando os valores nulos
data.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### **1.2. Variáveis numéricas**

# %% [markdown]
# Identifique as variáveis numéricas e crie uma nova coluna **padronizando** seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_std*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.2

data[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'flipper_length_mm', 'body_mass_g']].head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  flipper_length_mm  \
# 0            39.1           18.7              181.0              181.0
# 1            39.5           17.4              186.0              186.0
# 2            40.3           18.0              195.0              195.0
# 4            36.7           19.3              193.0              193.0
# 5            39.3           20.6              190.0              190.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 4       3450.0
# 5       3650.0

# %%
#para aplicar em várias colunas de uma vez, defini uma função:

def pad_coluna(data, nome_coluna):

    media = data[nome_coluna].mean()
    desvio_padrao = data[nome_coluna].std()

    data[f"{nome_coluna}_std"] = data[nome_coluna].apply(lambda x: (x - media) / desvio_padrao)

    return data

data = pad_coluna(data, 'bill_length_mm')
data = pad_coluna(data, 'bill_depth_mm')
data = pad_coluna(data, 'body_mass_g')
data = pad_coluna(data, 'flipper_length_mm')

data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_length_mm_std  bill_depth_mm_std  \
# 0       3750.0    Male           -0.894695           0.779559
# 1       3800.0  Female           -0.821552           0.119404
# 2       3250.0  Female           -0.675264           0.424091
# 4       3450.0  Female           -1.333559           1.084246
# 5       3650.0    Male           -0.858123           1.744400
#
#    body_mass_g_std  flipper_length_mm_std
# 0        -0.567621              -1.424608
# 1        -0.505525              -1.067867
# 2        -1.188572              -0.425733
# 4        -0.940192              -0.568429
# 5        -0.691811              -0.782474

# %% [markdown]
# ### **1.3. Variáveis categóricas**

# %% [markdown]
# Identifique as variáveis categóricas nominais e ordinais, crie uma nova coluna aplicando a técnica correta de conversão a seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_nom*" ou "*_ord*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.3

#Categóricos Nominais

data['sex'].head(10)

#Decodificação one hot encoding

data['sex_male_nom'] = data['sex'].apply(lambda sex: 1 if sex == 'Male' else 0)
data['sex_female_nom'] = data['sex'].apply(lambda sex: 1 if sex == 'Female' else 0)

data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_length_mm_std  bill_depth_mm_std  \
# 0       3750.0    Male           -0.894695           0.779559
# 1       3800.0  Female           -0.821552           0.119404
# 2       3250.0  Female           -0.675264           0.424091
# 4       3450.0  Female           -1.333559           1.084246
# 5       3650.0    Male           -0.858123           1.744400
#
#    body_mass_g_std  flipper_length_mm_std  sex_male  sex_female  sex_male_nom  \
# 0        -0.567621              -1.424608         1           0             1
# 1        -0.505525              -1.067867         0           1             0
# 2        -1.188572              -0.425733         0           1             0
# 4        -0.940192              -0.568429         0           1             0
# 5        -0.691811              -0.782474         1           0             1
#
#    sex_female_nom
# 0               0
# 1               1
# 2               1
# 4               1
# 5               0

# %%
# Categóricos Ordinais

#Não existem categóricos ordinais nos dados acima, uma vez que nenhum dos dados acima indica uma ordem.

# %% [markdown]
# ### **1.4. Limpeza**

# %% [markdown]
# Descarte as colunas originais e mantenha apenas a variável resposta e as variáveis preditivas com o sufixo *_std*", *_nom*" e "*_ord*".

# %%
# resposta da questão 1.4

data.drop(['island','bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex'], axis=1)
# Out:
#     species  bill_length_mm_std  bill_depth_mm_std  body_mass_g_std  \
# 0    Adelie           -0.894695           0.779559        -0.567621
# 1    Adelie           -0.821552           0.119404        -0.505525
# 2    Adelie           -0.675264           0.424091        -1.188572
# 4    Adelie           -1.333559           1.084246        -0.940192
# 5    Adelie           -0.858123           1.744400        -0.691811
# ..      ...                 ...                ...              ...
# 338  Gentoo            0.586470          -1.759497         0.891616
# 340  Gentoo            0.513326          -1.454811         0.798473
# 341  Gentoo            1.171621          -0.743875         1.916186
# 342  Gentoo            0.220750          -1.200905         1.233139
# 343  Gentoo            1.080191          -0.540750         1.481520
#
#      flipper_length_mm_std  sex_male  sex_female  sex_male_nom  sex_female_nom
# 0                -1.424608         1           0             1               0
# 1                -1.067867         0           1             0               1
# 2                -0.425733         0           1             0               1
# 4                -0.568429         0           1             0               1
# 5                -0.782474         1           0             1               0
# ..                     ...       ...         ...           ...             ...
# 338               0.929884         0           1             0               1
# 340               1.001232         0           1             0               1
# 341               1.500670         1           0             1               0
# 342               0.787187         0           1             0               1
# 343               0.858536         1           0             1               0
#
# [333 rows x 9 columns]

# %% [markdown]
# ---
